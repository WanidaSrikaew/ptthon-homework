# %%
class Student():
    def __init__(self, sid, cid, firstname, lastname ,age, gender):
        self.__sid= sid
        self.__cid = cid
        self.__firstname = firsname
        self.__lastname = lastname
        self.__age = age
        self.__gender = gender

        if len(newcard) == 13:
            self.__cid = cid
        else:
            print("หมายเลขบัตรต้องมีความยาว 13 หลักเท่านั้น")
            self.__cid = cid
    
    def setAge(self, newAge):
        if self.__age < newAge:
            self.__age = newAge
        else:
            print("อายุต้องเพิ่มขึ้นมากกว่าเดิมเท่านั้น")
            
    def setCid(self, cid)
        if len(cid) == 13 and selt.__cid == "":
            self.__cid = cid
        else:
            print("หมายเลขบัตรต้องมีความยาว 13 หลักเท่านั้น")
            self.__cid""

    def showInfo(self):
        print("""
        รหัสนักศึกษา: {}
        เลขบัตรประชาชน: {}
        ชื่อ: {} 
        นามสกุล: {}
        อายุ: {}
        เพศ: {}
        """.format(self.__sid, self.__cid, self.__firsname, self.__lastname, self.__age, self.__gender))

# %%
student_luna = stu('1234567891', '1234567891234', 'ลูน่า', 18, 'หญิง')
