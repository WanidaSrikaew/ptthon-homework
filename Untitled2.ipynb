# %%
lt = [9, 7, 3, 10]

pivot = lt[0]
left = [i for i in lt if i < pivot]
right = [i for i in lt if i > pivot]

# %%
print(left, pivot, right)
# Out:
# [7, 3] 9 [10]

# %%
pivot_2 = left[0]
left_2 = [i for i in lt if i < pivot_2]
right_2 = [i for i in lt if i > pivot_2]

# %%
print(left_2, pivot_2, right_2)
# Out:
# [3] 7 [9, 10]
